# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# /Users/manoj/Desktop/RAG/.venv/bin/python
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 11:23:37) [Clang 14.0.6 ]

# %%
import sys

print(sys.executable)
# Out:
# /Users/manoj/Desktop/RAG/.venv/bin/python
